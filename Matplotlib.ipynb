# %% [raw]
# # This is matplotlib tutorial

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel("Learn the curves")
plt.show()

# %% [raw]
# Code Explanation :
#
# Firstly we have imported the pyplot from matplotlib
# As the begenning exercise we have just given list of numbers to plot
# yLabel() : is used for naming conventions, to make it user friendly when other are going through your graphs
# Finally show() gives us the output
#
#
# Reason why we have 0-3 in x-axis and 1-4 ranges in y-axis is, whenever we have provided a single list or array to the plot it will consider it as y-axis and generates equivalent x-axis, Since python starts with 0, its 0-3

# %%
plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %% [raw]
# plot() command can take any number of arguments, above is the example to plot x versus y

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.show()

# %% [raw]
# By default we will get a line for the point we represent, It is always good to see the points.
# it can be done my adding an extra parameter to our plot() command which is "ro" which gives us the red dots
# "ro" --> for RED dots
# "bo" --> for BLUE dots
# "go" --> for GREEN dots
#
# In the above graph, Since we haven't mentioned axis specifiers the graph is generated based in the point
# lets trying giving axis specifiers

# %%
plt.plot([1,2,3,4],[1,4,9,16],"ro")
plt.axis([0,6,0,20])
plt.show()

# %% [raw]
# Here the axis() command takes the xMin,xMax,yMin,yMax

# %% [raw]
# Now lets trying ploting multiple values in the graph

# %%
import numpy as np
t = np.arange(0.,5.,0.2)
plt.plot(t,t,"r--",t,t**2,"bs",t,t**3,"g^")
plt.show()

# %% [raw]
# Here we are taking a list "t" ranging from 0 to 5 with .2 difference each and ploting a graph
# plot() command is so versatile that it can take multiple parameters and plot in a single graph
#
# If we observe closly we have differentiate each curve with different sign by providing a param, even though we didnt do that still the plt library generates in 3 different colors

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %% [raw]
# scatter() command helps in plotting keyword strings
#
# Code Explanation:
#
# plots are generated to the string corresponding to those variables in different sizes and colors
#
# Difference between plot() and scatter()
#
# scatter draws points without lines connecting them whereas plot may or may not plot the lines, depending on the arguments.
# scatter returns a handle to an object called scattergroup whereas plot returns a handle to an object called lineseries. The scattergroup object has some properties (for example, for associating the size of the dots to a variable in the workspace) that are not present in the lineseries objects. Analogously, the lineseries has some properties (for exmaple, for controlling the type of lines) that are not present in the scattergroup object.
# scatter allows you to specify a different colour and a different size for each point individually. It is not possible to do that with plot.
#
# REFERENCE : https://in.mathworks.com/matlabcentral/answers/80266-can-anyone-tell-me-what-is-the-difference-between-scatter-and-plot-commands-in-matlab

# %%
names = ['group_1','group_2','group_3']
values = [1,10,100]

plt.figure(figsize=(12,4))
plt.subplot(131)
plt.bar(names,values)
plt.subplot(132)
plt.scatter(names,values)
plt.subplot(133)
plt.plot(names,values)
plt.suptitle("Categoriacal Values")
plt.show()

# %% [raw]
# matplotlib allows to create graphs for categorical values

# %%
lines = plt.plot([1,2,3])
plt.setp(lines, color='g', linewidth=5.0)
plt.show()

# %%
plt.hist([1,2,3],5)
plt.show()
